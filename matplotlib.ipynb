# %% [markdown]
# # Matplotlib
#   A library for data visualization

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("E:MACHINE LEARNING/KNN/iris_prediction_knn1/Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# Scatter Plot

# %%
#Defining the data
roll_no = [1,2,3,4,5,6,7,8,9]
marks = [47,65,96,45,75,74,98,58,10]

# %%
plt.style.use("dark_background")

# %%
# Implementing Basic Scatter Plot
plt.figure(figsize=(12,6)) #..... change size of figure
plt.scatter(roll_no,marks)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# changing Color of the plotted Points
plt.scatter(roll_no,marks,color="orange")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# changing Marker of the Plotted Points
plt.scatter(roll_no,marks,color="red",marker="v")
plt.show()

# %%
#More fuctions using Plot Function
plt.figure(figsize=(12,8))
plt.plot(roll_no,marks,"gv",markersize=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Multiple Plot on same Figure
temperature_pune = [25,34,21,45,28,6,43,18,7,2]
humidity_pune = [28,25,29,20,26,50,19,29,52,55]

temperature_bangalore = [34,35,36,37,28,27,26,25,31,20]
humidity_bangalore = [40,38,36,35,42,44,14,40,34,45]

# %%
plt.figure(figsize=(12,8))
plt.xticks(np.arange(0,60,5))
plt.yticks(np.arange(10,60,5))
plt.plot(temperature_pune,humidity_pune,"y*",markersize=15)
plt.plot(temperature_bangalore,humidity_bangalore,"gv",markersize=10)
plt.xlabel("Tempreture")
plt.ylabel("Humidity")
plt.show()

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.scatter(df["SepalLengthCm"],df["SepalWidthCm"])
plt.show()

# %%
plt.plot(df["SepalLengthCm"],df["PetalLengthCm"],"go")
plt.show()

# %%
plt.plot(df["Species"],df["SepalWidthCm"],"ro",alpha=0.5,markersize=8)

# %% [markdown]
# # Line plot

# %%
plt.plot(roll_no,marks,"r-")

# %%
plt.plot(roll_no,marks,linestyle="--")

# %%
plt.plot(roll_no,marks,linestyle=":",color ="orange")

# %% [markdown]
# solid(default)"-"
#
# dotted ":"
#
# dashes "--"
#
# none " "

# %%
plt.figure(figsize=(12,6))
plt.plot(roll_no,marks,linestyle="-.",color="orange",linewidth=15)

# %%
df.head(1)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa

# %%
plt.figure(figsize=(12,8))
plt.plot(df["Species"],linestyle="-",color="yellow")
plt.plot(df["Species"],"bo")

# %%
plt.bar(df["Species"],df["SepalWidthCm"],color="red",alpha=0.2)
# Out:
# <BarContainer object of 150 artists>

# %%
colors=["green","white","orange"]
plt.bar(df["Species"],df["PetalLengthCm"],color=colors,width=0.2,edgecolor="red",linestyle="-.")
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.barh(df["Species"],df["PetalLengthCm"],color="yellow",edgecolor="red",linestyle="-.")
# Out:
# <BarContainer object of 150 artists>

# %%
Species_len=np.arange(len(df["Species"]))
width =0.4
plt.bar(Species_len,df["PetalLengthCm"],width=width)
plt.bar(Species_len+5+width,df["SepalLengthCm"],width=width)
# Out:
# <BarContainer object of 150 artists>

# %% [markdown]
# # Pie Chart

# %%
values=[0.1,0.2,0]
plt.pie(df["PetalWidthCm"],labels=df["Species"])
# Out:
# ([<matplotlib.patches.Wedge at 0x1c52f0fec10>,
# ...
#  [Text(1.0999932835069293, 0.0038439874667143326, 'Iris-setosa'),
#   Text(1.099939552054486, 0.011531774632605815, 'Iris-setosa'),
#   Text(1.0998320917742228, 0.01921899850505765, 'Iris-setosa'),
#   Text(1.099670907915261, 0.02690528358568259, 'Iris-setosa'),
#   Text(1.0994560083509595, 0.03459025442195065, 'Iris-setosa'),
#   Text(1.09903296573699, 0.04611442532827156, 'Iris-setosa'),
#   Text(1.098386755357154, 0.05955279721376251, 'Iris-setosa'),
#   Text(1.0978245714021946, 0.06914629726592639, 'Iris-setosa'),
#   Text(1.0973144934124537, 0.07681733233437767, 'Iris-setosa'),
#   Text(1.0968967580644522, 0.08256816667272647, 'Iris-setosa'),
#   Text(1.096448883802392, 0.08831673232456397, 'Iris-setosa'),
#   Text(1.095804856753358, 0.09597768446755117, 'Iris-setosa'),
#   Text(1.0952867076459467, 0.10172034238097338, 'Iris-setosa'),
#   Text(1.0949245547306699, 0.10554723799249617, 'Iris-setosa'),
# ...

# %%
Species_df=pd.DataFrame(df["Species"].value_counts())
species
# Out:
#                  count
# Species
# Iris-setosa         50
# Iris-versicolor     50
# Iris-virginica      50

# %%
plt.pie(Species_df["Species"],lables=Species,colors=["red","blue","green"],autopct="%0.2f%%")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Species'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[211], line 1
# ...
