# %%
import pandas as pd

# %%
df = pd.read_csv("/content/successful_educations.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-7595f6ba8e6c> in <cell line: 0>()
# ----> 1 df = pd.read_csv("/content/successful_educations.csv")
#       2 df
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/successful_educations.csv'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Name                       108 non-null    object
#  1   Profession                 108 non-null    object
#  2   Degree                     106 non-null    object
#  3   Field                      105 non-null    object
#  4   Institution                106 non-null    object
#  5   Graduation Year            99 non-null     float64
#  6   Country                    108 non-null    object
#  7   University Global Ranking  73 non-null     object
#  8   GPA (or Equivalent)        93 non-null     object
#  9   Scholarship/Award          80 non-null     object
# dtypes: float64(1), object(9)
# memory usage: 8.6+ KB

# %%
# for count of "Null" values
df.isnull().sum()
# Out:
# Name                          0
# Profession                    0
# Degree                        2
# Field                         3
# Institution                   2
# Graduation Year               9
# Country                       0
# University Global Ranking    35
# GPA (or Equivalent)          15
# Scholarship/Award            28
# dtype: int64

# %%
#How many different types of Degrees?
df["Degree"].unique()
# Out:
# array(['Bachelor of Science', 'Dropped Out', 'Master of Science',
#        'Master of Business Administration', 'Honorary Doctorate',
#        'Undergraduate Studies', 'Doctor of Philosophy', 'Juris Doctor',
#        'Master of Arts', 'Bachelor of Arts', 'High School', 'PhD',
#        'Bachelor', nan, 'Master', 'MBA', 'Master/MBA', 'MD', 'Dropout',
#        'Engineering', 'No Degree'], dtype=object)

# %%
df["Profession"].unique()
# Out:
# array(['Entrepreneur', 'Tech Executive', 'Business Leader',
#        'Media Executive', 'Activist', 'Scientist', 'Politician',
#        'Athlete', 'Author', 'Actor', 'Lawyer/Author', 'Physicist',
#        'Tech CEO', 'Astrophysicist', 'Philanthropist',
#        'Business Executive', 'Musician', 'Author/Philanthropist',
#        'Nonprofit Executive', 'Education Executive', 'TV Host/Author',
#        'Actor/Comedian', 'Journalist', 'Actor/Writer', 'Film Director',
#        'TV Host/Designer', 'Comedian', 'Actor/Singer', 'Actor/Podcaster',
#        'Actor/Scientist', 'Comedian/Actor', 'Investor', 'Business',
#        'Finance', 'Fashion'], dtype=object)

# %%
df["Field"].unique()
# Out:
# array(['Physics & Economics', 'computer science',
#        'Material Sciences and Engineering', 'Business Administration',
#        'Computer Science and Electrical Engineering', 'Management',
#        'speech communications and performing arts', 'Computer Science',
#        'Philosophy', 'computer science and psychology', 'Physics', 'Law',
#        'Computer Engineering', 'Physical Chemistry', 'Sociology',
#        'English Literature', 'General', 'French/Classics', 'Drama',
#        'English', 'Astrophysics', 'Business', nan, 'Economics',
#        'Liberal Arts', 'Electrical Engineering', 'Medicine',
#        'Television & Radio', 'Engineering/Business', 'Theatre Arts',
#        'Biology', 'Political Science', 'Playwriting',
#        'Computer Science/Philosophy', 'English/African American Studies',
#        'Fashion Management', 'Creative Writing', 'Music', 'Anthropology',
#        'Neuroscience', 'Experimental Film', 'Psychology', 'Mathematics',
#        'Engineering', 'Commerce', 'Software Engineering',
#        'Animal Science', 'mechanical engineering', 'Pharmacy'],
#       dtype=object)

# %%
df["Country"].unique()
# Out:
# array(['USA', 'UK', 'France', 'Germany', 'Canada', 'China',
#        'South Africa', 'India', 'Mexico', 'Australia', 'Switzerland',
#        'Italy', 'Japan', 'Austria', 'Azerbaijan'], dtype=object)

# %%
df["Country"].value_counts()
# Out:
# Country
# USA             69
# China           12
# UK               5
# France           4
# Germany          4
# India            3
# Mexico           2
# Japan            2
# Canada           1
# South Africa     1
# Australia        1
# Switzerland      1
# Italy            1
# Austria          1
# Azerbaijan       1
# Name: count, dtype: int64

# %%
df_ger = df[df["Country"]=="Germany"]
df_ger
# Out:
#                      Name  Profession                Degree  \
# 16          Angela Merkel  Politician  Doctor of Philosophy
# 35   Ursula von der Leyen  Politician                   PhD
# 105         Stefan Quandt    Business              Bachelor
# 106       Susanne Klatten    Business              Bachelor
#
#                   Field                        Institution  Graduation Year  \
# 16   Physical Chemistry              University of Leipzig           1986.0
# 35             Medicine            Hannover Medical School           1991.0
# 105         Engineering  Technical University of Darmstadt           1994.0
# 106           Economics     Technical University of Munich           1993.0
#
#      Country University Global Ranking GPA (or Equivalent)  \
# 16   Germany                   231–240                 NaN
# 35   Germany                       122     Magna Cum Laude
# 105  Germany                       NaN                 3.7
# 106  Germany                       NaN                 3.8
#
#              Scholarship/Award
# 16            DAAD Scholarship
# 35   Research Excellence Award
# 105                        NaN
# 106                        NaN

# %%
df_ger[df_ger["Field"]=="Economics"]
# Out:
#                 Name Profession    Degree      Field  \
# 106  Susanne Klatten   Business  Bachelor  Economics
#
#                         Institution  Graduation Year  Country  \
# 106  Technical University of Munich           1993.0  Germany
#
#     University Global Ranking GPA (or Equivalent) Scholarship/Award
# 106                       NaN                 3.8               NaN

# %%
df_USA = df[df["Country"]=="USA"]
df_USA
# Out:
#                 Name      Profession                             Degree  \
# 0          Elon Musk    Entrepreneur                Bachelor of Science
# 1         Bill Gates    Entrepreneur                        Dropped Out
# 2      Sundar Pichai  Tech Executive                  Master of Science
# 3    Sheryl Sandberg  Tech Executive  Master of Business Administration
# 4         Jeff Bezos    Entrepreneur                Bachelor of Science
# ..               ...             ...                                ...
# 87       Colin Huang    Entrepreneur                             Master
# 89         Wang Xing    Entrepreneur                             Master
# 98      Alice Walton        Business                           Bachelor
# 102      Ken Griffin         Finance                           Bachelor
# 103  Eduardo Saverin    Entrepreneur                           Bachelor
#
#                                            Field                 Institution  \
# 0                            Physics & Economics  University of Pennsylvania
# 1                               computer science          Harvard University
# 2              Material Sciences and Engineering         Stanford University
# 3                        Business Administration     Harvard Business School
# 4    Computer Science and Electrical Engineering        Princeton University
# ..                                           ...                         ...
# 87                              Computer Science     University of Wisconsin
# 89                              Computer Science      University of Delaware
# 98                                     Economics             Trinity College
# 102                                    Economics          Harvard University
# 103                                    Economics          Harvard University
#
#      Graduation Year Country University Global Ranking GPA (or Equivalent)  \
# 0             1997.0     USA                        13                 3.7
# 1             1975.0     USA                         5                 NaN
# 2             1995.0     USA                         3                 3.8
# 3             1995.0     USA                         2                 3.9
# 4             1986.0     USA                        16                 3.6
# ..               ...     ...                       ...                 ...
# 87            2004.0     USA                        28                 4.0
# 89            2005.0     USA                       137                 3.9
# 98            1971.0     USA                         3                 3.7
# 102           1989.0     USA                         3                 3.8
# 103           2006.0     USA                         3                 3.7
#
#              Scholarship/Award
# 0                  Dean’s List
# 1                  Dean’s List
# 2    Fellowship in Engineering
# 3            Hoover Fellowship
# 4              Marquis Scholar
# ..                         ...
# 87         Research Fellowship
# 89           Merit Scholarship
# 98                         NaN
# 102                        NaN
# 103                        NaN
#
# [69 rows x 10 columns]

# %%
df_USA[df_USA["Degree"]=="Dropped Out"]
# Out:
#               Name    Profession       Degree  \
# 1       Bill Gates  Entrepreneur  Dropped Out
# 9  Mark Zuckerberg  Entrepreneur  Dropped Out
#
#                              Field         Institution  Graduation Year  \
# 1                 computer science  Harvard University           1975.0
# 9  computer science and psychology  Harvard University              NaN
#
#   Country University Global Ranking GPA (or Equivalent) Scholarship/Award
# 1     USA                         5                 NaN       Dean’s List
# 9     USA                         5                 NaN               NaN

# %%
df[df['Degree']=="Dropped Out"]
# Out:
#               Name    Profession       Degree  \
# 1       Bill Gates  Entrepreneur  Dropped Out
# 9  Mark Zuckerberg  Entrepreneur  Dropped Out
#
#                              Field         Institution  Graduation Year  \
# 1                 computer science  Harvard University           1975.0
# 9  computer science and psychology  Harvard University              NaN
#
#   Country University Global Ranking GPA (or Equivalent) Scholarship/Award
# 1     USA                         5                 NaN       Dean’s List
# 9     USA                         5                 NaN               NaN

# %%
df["Degree"].replace(to_replace="Dropout", value="Dropped Out", inplace=True)
# Out:
# <ipython-input-31-dcb534a976fe>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Degree"].replace(to_replace="Dropout", value="Dropped Out", inplace=True)

# %%
df["Degree"].unique()
# Out:
# array(['Bachelor of Science', 'Dropped Out', 'Master of Science',
#        'Master of Business Administration', 'Honorary Doctorate',
#        'Undergraduate Studies', 'Doctor of Philosophy', 'Juris Doctor',
#        'Master of Arts', 'Bachelor of Arts', 'High School', 'PhD',
#        'Bachelor', nan, 'Master', 'MBA', 'Master/MBA', 'MD',
#        'Engineering', 'No Degree'], dtype=object)

# %%
df[df["Graduation Year"]>2000]
# Out:
#                    Name           Profession                 Degree  \
# 8      Malala Yousafzai             Activist  Undergraduate Studies
# 13      Serena Williams              Athlete    Bachelor of Science
# 18          Emma Watson                Actor       Bachelor of Arts
# 37       Reshma Saujani  Nonprofit Executive           Juris Doctor
# 38             Sal Khan  Education Executive             Master/MBA
# 47         Mindy Kaling         Actor/Writer               Bachelor
# 48      Kumail Nanjiani       Actor/Comedian               Bachelor
# 51   Chimamanda Adichie               Author                 Master
# 53        Reshma Shetty         Actor/Singer                 Master
# 55         Mayim Bialik      Actor/Scientist                    PhD
# 57      Natalie Portman                Actor               Bachelor
# 82         Zhang Yiming         Entrepreneur               Bachelor
# 87          Colin Huang         Entrepreneur                 Master
# 89            Wang Xing         Entrepreneur                 Master
# 101     Mark Mateschitz             Business               Bachelor
# 103     Eduardo Saverin         Entrepreneur               Bachelor
#
#                            Field               Institution  Graduation Year  \
# 8                     Philosophy      University of Oxford           2021.0
# 13       Business Administration  University of California           2021.0
# 18            English Literature          Brown University           2014.0
# 37                           Law           Yale Law School           2002.0
# 38          Engineering/Business               MIT/Harvard           2003.0
# 47                   Playwriting         Dartmouth College           2001.0
# 48   Computer Science/Philosophy          Grinnell College           2001.0
# 51              Creative Writing  Johns Hopkins University           2003.0
# 53                         Music    University of Kentucky           2003.0
# 55                  Neuroscience                      UCLA           2007.0
# 57                    Psychology        Harvard University           2003.0
# 82          Software Engineering         Nankai University           2005.0
# 87              Computer Science   University of Wisconsin           2004.0
# 89              Computer Science    University of Delaware           2005.0
# 101                    Economics   Fachhochschule Salzburg           2018.0
# 103                    Economics        Harvard University           2006.0
#
#      Country University Global Ranking  GPA (or Equivalent)  \
# 8         UK                         4  First Class Honours
# 13       USA                        40                  3.6
# 18       USA                        14                  3.5
# 37       USA                         1                  3.8
# 38       USA                         1                  4.0
# 47       USA                        12                  3.7
# 48       USA                       NaN                  3.6
# 51       USA                        10                  3.9
# 53       USA                       NaN                  3.8
# 55       USA                        15                  4.0
# 57       USA                         3                  3.9
# 82     China                       NaN                  3.9
# 87       USA                        28                  4.0
# 89       USA                       137                  3.9
# 101  Austria                       NaN                  3.8
# 103      USA                         3                  3.7
#
#                   Scholarship/Award
# 8                 Nobel Peace Prize
# 13   Student-Athlete Academic Award
# 18          Rhodes Scholar Finalist
# 37        Paul & Daisy Soros Fellow
# 38             Presidential Scholar
# 47              Eleanor Frost Prize
# 48                     Comedy Award
# 51             MacArthur Fellowship
# 53           Opera Excellence Award
# 55              Neuroscience Fellow
# 57                   Research Award
# 82              Academic Excellence
# 87              Research Fellowship
# 89                Merit Scholarship
# 101                             NaN
# 103                             NaN

# %% [markdown]
# What is the average graduation year of individuals in the dataset?
#
# Which profession has the highest average GPA?
#
# What is the most common field of study among the individuals?
#
# How many individuals received a scholarship or award?
#
# What is the distribution of individuals by country?
#
# Which university appears most frequently in the dataset?
#
# What is the average university global ranking for tech executives?
#
# How many individuals graduated after the year 2000?
#
# What is the most common degree among entrepreneurs?
#
# Which institution has the highest average GPA?
#
# What is the correlation between graduation year and GPA (if numeric)?
#
# How many individuals have a Master’s degree or higher?
#
# What is the average GPA by field of study?
#
# Which profession has the most recipients of scholarships or awards?
#
# What is the average global ranking of universities attended by individuals from the USA?
#
# How many individuals did not complete a degree (e.g., Dropped Out)?
#
# Which field has the most graduates?
#
# What is the average graduation year for each profession?
#
# How many individuals attended Ivy League schools?
#
# Which university produced the most entrepreneurs in the dataset?

# %%
#Which profession has the highest average GPA?

d

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/addiction_population_data.csv")
df
# Out:
#         id              name  age  gender                      country  \
# 0        1     Michael Bates   66   Other                        Yemen
# 1        2    Brian Thompson   29    Male                 Saudi Arabia
# 2        3     Steven Little   75    Male                         Togo
# 3        4   Michael Mathews   35   Other                         Togo
# 4        5  Nicholas Sanchez   38  Female                      Morocco
# ...    ...               ...  ...     ...                          ...
# 2995  2996     Mary Bartlett   29   Other                    Macedonia
# 2996  2997      Beth Sanchez   51    Male                 Saudi Arabia
# 2997  2998       Megan Duffy   15    Male  Falkland Islands (Malvinas)
# 2998  2999    Jeffery Lawson   38    Male                      Bermuda
# 2999  3000      Kathryn Gray   41   Other                      Jamaica
#
#                city education_level employment_status  annual_income_usd  \
# 0       Martinmouth       Secondary           Student              45595
# 1       Harperhaven         Primary     Self-Employed             145842
# 2          Chanport    Postgraduate        Unemployed             162480
# 3        North Cory      University        Unemployed              16023
# 4        Danielberg         College     Self-Employed              62933
# ...             ...             ...               ...                ...
# 2995  Port Kimberly    Postgraduate          Employed             118269
# 2996      Smithbury         College          Employed              35898
# 2997      Clinebury         College           Retired             167501
# 2998    Colleenport       Secondary           Retired             135893
# 2999     Turnertown             NaN          Employed             124049
#
#          marital_status  ...  attempts_to_quit_smoking  \
# 0               Married  ...                         6
# 1                Single  ...                         1
# 2                Single  ...                         9
# 3     In a relationship  ...                         5
# 4     In a relationship  ...                         4
# ...                 ...  ...                       ...
# 2995             Single  ...                         9
# 2996            Widowed  ...                         9
# 2997            Widowed  ...                         1
# 2998            Married  ...                         9
# 2999             Single  ...                         3
#
#       attempts_to_quit_drinking  has_health_issues  mental_health_status  \
# 0                             2               True                  Good
# 1                             6              False                  Poor
# 2                             9               True                  Good
# 3                             7              False               Average
# 4                             7               True                  Poor
# ...                         ...                ...                   ...
# 2995                          1               True                  Poor
# 2996                          2               True                  Poor
# 2997                          8               True                  Poor
# 2998                          3              False                  Poor
# 2999                          5              False                  Good
#
#       exercise_frequency  diet_quality  sleep_hours   bmi social_support  \
# 0                  Daily       Average          5.6  22.4            NaN
# 1                 Weekly          Good          6.7  24.1       Moderate
# 2                  Never          Good          6.2  22.2           Weak
# 3                  Daily          Good          7.2  25.5       Moderate
# 4                 Weekly          Good          8.5  31.2           Weak
# ...                  ...           ...          ...   ...            ...
# 2995               Never       Average          6.6  27.4       Moderate
# 2996              Rarely          Good          4.3  27.7       Moderate
# 2997              Rarely          Poor          6.6  23.5       Moderate
# 2998              Rarely          Poor          4.9  27.2            NaN
# 2999               Daily       Average          5.2  19.6       Moderate
#
#      therapy_history
# 0            Current
# 1                NaN
# 2                NaN
# 3            Current
# 4               Past
# ...              ...
# 2995         Current
# 2996            Past
# 2997            Past
# 2998         Current
# 2999            Past
#
# [3000 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         3000 non-null   int64
#  1   name                       3000 non-null   object
#  2   age                        3000 non-null   int64
#  3   gender                     3000 non-null   object
#  4   country                    3000 non-null   object
#  5   city                       3000 non-null   object
#  6   education_level            2580 non-null   object
#  7   employment_status          3000 non-null   object
#  8   annual_income_usd          3000 non-null   int64
#  9   marital_status             3000 non-null   object
#  10  children_count             3000 non-null   int64
#  11  smokes_per_day             3000 non-null   int64
#  12  drinks_per_week            3000 non-null   int64
#  13  age_started_smoking        3000 non-null   int64
#  14  age_started_drinking       3000 non-null   int64
#  15  attempts_to_quit_smoking   3000 non-null   int64
#  16  attempts_to_quit_drinking  3000 non-null   int64
#  17  has_health_issues          3000 non-null   bool
#  18  mental_health_status       3000 non-null   object
#  19  exercise_frequency         3000 non-null   object
#  20  diet_quality               3000 non-null   object
#  21  sleep_hours                3000 non-null   float64
#  22  bmi                        3000 non-null   float64
#  23  social_support             2247 non-null   object
#  24  therapy_history            1986 non-null   object
# dtypes: bool(1), float64(2), int64(10), object(12)
# memory usage: 565.6+ KB

# %%
df["gender"].value_counts()
# Out:
# gender
# Other     1024
# Female    1017
# Male       959
# Name: count, dtype: int64

# %%
df.groupby("gender")["education_level"].value_counts()
# Out:
# gender  education_level
# Female  High School        171
#         Postgraduate       151
#         University         149
#         Primary            145
#         Secondary          142
#         College            138
# Male    Postgraduate       150
#         University         145
#         College            133
#         Primary            132
#         Secondary          129
#         High School        118
# Other   University         170
#         Postgraduate       146
#         Secondary          144
#         Primary            140
#         High School        139
#         College            138
# Name: count, dtype: int64

# %%
df.groupby("gender")["exercise_frequency"].value_counts()
# Out:
# gender  exercise_frequency
# Female  Rarely                268
#         Never                 265
#         Daily                 246
#         Weekly                238
# Male    Never                 255
#         Rarely                246
#         Weekly                231
#         Daily                 227
# Other   Rarely                265
#         Daily                 264
#         Never                 254
#         Weekly                241
# Name: count, dtype: int64

# %%
df.groupby("mental_health_status")["sleep_hours"].mean()
# Out:
# mental_health_status
# Average    6.424582
# Good       6.475549
# Poor       6.512640
# Name: sleep_hours, dtype: float64

# %%
# name that start with "M"
df[df["name"].str.startswith("M")]
# Out:
#         id                name  age  gender                      country  \
# 0        1       Michael Bates   66   Other                        Yemen
# 3        4     Michael Mathews   35   Other                         Togo
# 8        9      Melanie Walker   16   Other                 Burkina Faso
# 11      12  Michael Parker DDS   16   Other                        Benin
# 46      47      Michael Powell   49  Female                        Aruba
# ...    ...                 ...  ...     ...                          ...
# 2979  2980       Marie Pearson   40    Male                       Kuwait
# 2982  2983        Manuel Moore   61   Other                       France
# 2991  2992   Michael Christian   55    Male                  Afghanistan
# 2995  2996       Mary Bartlett   29   Other                    Macedonia
# 2997  2998         Megan Duffy   15    Male  Falkland Islands (Malvinas)
#
#                     city education_level employment_status  annual_income_usd  \
# 0            Martinmouth       Secondary           Student              45595
# 3             North Cory      University        Unemployed              16023
# 8             Brandystad    Postgraduate           Retired              85495
# 11    North Tiffanyhaven       Secondary           Retired             123308
# 46          Timothymouth    Postgraduate           Retired             167089
# ...                  ...             ...               ...                ...
# 2979         New Nichole       Secondary           Student             192650
# 2982           Reyesstad         Primary          Employed              27155
# 2991          Petersport    Postgraduate        Unemployed              83623
# 2995       Port Kimberly    Postgraduate          Employed             118269
# 2997           Clinebury         College           Retired             167501
#
#          marital_status  ...  attempts_to_quit_smoking  \
# 0               Married  ...                         6
# 3     In a relationship  ...                         5
# 8              Divorced  ...                         6
# 11             Divorced  ...                         6
# 46              Married  ...                         1
# ...                 ...  ...                       ...
# 2979            Widowed  ...                         1
# 2982             Single  ...                         9
# 2991            Married  ...                         4
# 2995             Single  ...                         9
# 2997            Widowed  ...                         1
#
#       attempts_to_quit_drinking  has_health_issues  mental_health_status  \
# 0                             2               True                  Good
# 3                             7              False               Average
# 8                             5              False                  Good
# 11                            2              False               Average
# 46                            5              False                  Poor
# ...                         ...                ...                   ...
# 2979                          3               True                  Poor
# 2982                          9               True                  Poor
# 2991                          5               True                  Poor
# 2995                          1               True                  Poor
# 2997                          8               True                  Poor
#
#       exercise_frequency  diet_quality  sleep_hours   bmi social_support  \
# 0                  Daily       Average          5.6  22.4            NaN
# 3                  Daily          Good          7.2  25.5       Moderate
# 8                 Weekly          Good          4.6  24.6            NaN
# 11                Weekly       Average          6.4  30.2           Weak
# 46                Rarely          Good          4.8  30.1            NaN
# ...                  ...           ...          ...   ...            ...
# 2979              Weekly          Good          7.4  22.7       Moderate
# 2982              Weekly          Good          6.4  26.0            NaN
# 2991              Weekly          Good          5.6  26.9           Weak
# 2995               Never       Average          6.6  27.4       Moderate
# 2997              Rarely          Poor          6.6  23.5       Moderate
#
#      therapy_history
# 0            Current
# 3            Current
# 8                NaN
# 11              Past
# 46               NaN
# ...              ...
# 2979             NaN
# 2982         Current
# 2991            Past
# 2995         Current
# 2997            Past
#
# [326 rows x 25 columns]

# %%
df["country"].value_counts().idxmax()
# Out:
# 'Korea'

# %%
df["country"].value_counts().idxmin()
# Out:
# 'Norfolk Island'

# %%
df=pd.read_csv("/content/vg_data_dictionary.csv")
df
# Out:
#            Field                                     Description
# 0            img        URL slug for the box art at vgchartz.com
# 1          title                                      Game title
# 2        console               Console the game was released for
# 3          genre                               Genre of the game
# 4      publisher                           Publisher of the game
# 5      developer                           Developer of the game
# 6   critic_score                    Metacritic score (out of 10)
# 7    total_sales              Global sales of copies in millions
# 8       na_sales      North American sales of copies in millions
# 9       jp_sales            Japanese sales of copies in millions
# 10     pal_sales  European & African sales of copies in millions
# 11   other_sales       Rest of world sales of copies in millions
# 12  release_date                   Date the game was released on
# 13   last_update                  Date the data was last updated

# %%
pf =pd.read_csv("/content/vgchartz-2024.csv")
pf
# Out:
#                                                  img  \
# 0      /games/boxart/full_6510540AmericaFrontccc.jpg
# 1      /games/boxart/full_5563178AmericaFrontccc.jpg
# 2                        /games/boxart/827563ccc.jpg
# 3      /games/boxart/full_9218923AmericaFrontccc.jpg
# 4      /games/boxart/full_4990510AmericaFrontccc.jpg
# ...                                              ...
# 64011  /games/boxart/full_2779838AmericaFrontccc.jpg
# 64012  /games/boxart/full_8031506AmericaFrontccc.jpg
# 64013  /games/boxart/full_6553045AmericaFrontccc.jpg
# 64014    /games/boxart/full_6012940JapanFrontccc.png
# 64015                      /games/boxart/default.jpg
#
#                                   title console         genre  \
# 0                    Grand Theft Auto V     PS3        Action
# 1                    Grand Theft Auto V     PS4        Action
# 2           Grand Theft Auto: Vice City     PS2        Action
# 3                    Grand Theft Auto V    X360        Action
# 4             Call of Duty: Black Ops 3     PS4       Shooter
# ...                                 ...     ...           ...
# 64011             XBlaze Lost: Memories      PC  Visual Novel
# 64012                      Yoru, Tomosu     PS4  Visual Novel
# 64013                      Yoru, Tomosu      NS  Visual Novel
# 64014   Yunohana SpRING! ~Mellow Times~      NS  Visual Novel
# 64015  Yurukill: The Calumniation Games     PS4  Visual Novel
#
#                   publisher             developer  critic_score  total_sales  \
# 0            Rockstar Games        Rockstar North           9.4        20.32
# 1            Rockstar Games        Rockstar North           9.7        19.39
# 2            Rockstar Games        Rockstar North           9.6        16.15
# 3            Rockstar Games        Rockstar North           NaN        15.86
# 4                Activision              Treyarch           8.1        15.09
# ...                     ...                   ...           ...          ...
# 64011           Aksys Games      Arc System Works           NaN          NaN
# 64012  Nippon Ichi Software  Nippon Ichi Software           NaN          NaN
# 64013  Nippon Ichi Software  Nippon Ichi Software           NaN          NaN
# 64014          Idea Factory               Otomate           NaN          NaN
# 64015               Unknown            G.rev Ltd.           NaN          NaN
#
#        na_sales  jp_sales  pal_sales  other_sales release_date last_update
# 0          6.37      0.99       9.85         3.12   2013-09-17         NaN
# 1          6.06      0.60       9.71         3.02   2014-11-18  2018-01-03
# 2          8.41      0.47       5.49         1.78   2002-10-28         NaN
# 3          9.06      0.06       5.33         1.42   2013-09-17         NaN
# 4          6.18      0.41       6.05         2.44   2015-11-06  2018-01-14
# ...         ...       ...        ...          ...          ...         ...
# 64011       NaN       NaN        NaN          NaN   2016-08-11  2019-01-28
# 64012       NaN       NaN        NaN          NaN   2020-07-30  2020-05-09
# 64013       NaN       NaN        NaN          NaN   2020-07-30  2020-05-09
# 64014       NaN       NaN        NaN          NaN   2019-02-28  2019-02-24
# 64015       NaN       NaN        NaN          NaN          NaN  2023-09-29
#
# [64016 rows x 14 columns]

# %%
pf["console"].value_counts()
# Out:
# console
# PC      12617
# PS2      3565
# DS       3288
# PS4      2878
# PS       2707
#         ...
# CD32        3
# C128        1
# FDS         1
# Aco         1
# BBCM        1
# Name: count, Length: 81, dtype: int64

# %%
pf.head(1)
# Out:
#                                              img               title console  \
# 0  /games/boxart/full_6510540AmericaFrontccc.jpg  Grand Theft Auto V     PS3
#
#     genre       publisher       developer  critic_score  total_sales  \
# 0  Action  Rockstar Games  Rockstar North           9.4        20.32
#
#    na_sales  jp_sales  pal_sales  other_sales release_date last_update
# 0      6.37      0.99       9.85         3.12   2013-09-17         NaN

# %%
# games release_date in month "08"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-0cf4bd6e5a11> in <cell line: 0>()
#       1 # games release_date in month "08"
# ----> 2 pf[pf["release_date"].str.startswith("08")]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4090
#    4091         # Do we have a (boolean) 1d indexer?
# -> 4092         if com.is_bool_indexer(key):
#    4093             return self._getitem_bool_array(key)
#    4094
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/common.py in is_bool_indexer(key)
#     134                     # Don't raise on e.g. ["A", "B", np.nan], see
#     135                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 136                     raise ValueError(na_msg)
#     137                 return False
#     138             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values
